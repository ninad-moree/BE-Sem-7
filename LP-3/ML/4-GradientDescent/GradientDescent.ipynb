# %%
start_x = 2
rate = 0.01
precision = 0.00001
step_size = 1
max_iteration = 10000
iterations = 0
df = lambda x : (x+3)**2
gd = []

# %%
while step_size > precision and iterations < max_iteration:
    prev = start_x
    start_x -= rate*df(prev)
    step_size = abs(prev - start_x)
    iterations += 1
    gd.append(start_x)
    # print(f"Iterations: {iterations}, Value: {start_x}")

# %%
print("Local Minima Occur at: ", start_x)
# Out:
# Local Minima Occur at:  -2.968395332539857

# %%
import seaborn as sns
sns.scatterplot(data=gd)
# Out:
# <AxesSubplot:>
